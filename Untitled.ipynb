# %%
import pandas as pd
df = pd.read_csv("teste.csv")
df
# Out:
#    field_od16_sua_faixa_etaria[und]  field_od16_possui_deficiencia_[und]  \
# 0                                 2                                    2
# 1                                 5                                    2
# 2                                 4                                    2
#
#    field_od16_tipo_deficiencia[und][1]  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
#
#    field_od16_qual_deficiencia_[und][0][value]  field_od16_sexo[und]  \
# 0                                          NaN                     1
# 1                                          NaN                     2
# 2                                          NaN                     1
#
#    field_od16_endereco[und][0][postal_code]  \
# 0                                  50690820
# 1                                  51350160
# 2                                  50820580
#
# ...

# %%
for index, row in df.iterrows():
    print (row)
# Out:
# field_od16_sua_faixa_etaria[und]                           2
# field_od16_possui_deficiencia_[und]                        2
# field_od16_tipo_deficiencia[und][1]                      NaN
# field_od16_qual_deficiencia_[und][0][value]              NaN
# field_od16_sexo[und]                                       1
# field_od16_endereco[und][0][postal_code]            50690820
# field_od16_endereco[und][0][thoroughfare]                NaN
# field_od16_endereco[und][0][premise]                     NaN
# field_od16_endereco[und][0][dependent_locality]          NaN
# field_od16_endereco[und][0][locality]                    NaN
# field_od16_endereco[und][0][administrative_area]         NaN
# field_od16_possui_f_esco_fund_me[und]                      2
# field_od16_qts_filhos_escola_fun[und]                    NaN
# field_od16_ql_transp_filhos_esc[und]                     NaN
# field_onde_guarda_bike_1[und]                            NaN
# ...
